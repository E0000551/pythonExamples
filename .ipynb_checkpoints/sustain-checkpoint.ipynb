# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('global-data-on-sustainable-energy.csv', encoding='ISO-8859-1')

# %%
df = df.rename(columns={
        "Entity":"Pais",
        "Year":"Año", 
        "Access to electricity (% of population)":"accessElectricity", 
        "Access to clean fuels for cooking":"cleanFuels",
        "Renewable-electricity-generating-capacity-per-capita": "renewElectricity"}
    )

# %%
df
# Out:
#              Pais   Año  accessElectricity  cleanFuels  renewElectricity  \
# 0     Afghanistan  2000           1.613591         6.2              9.22
# 1     Afghanistan  2001           4.074574         7.2              8.86
# 2     Afghanistan  2002           9.409158         8.2              8.47
# 3     Afghanistan  2003          14.738506         9.5              8.09
# 4     Afghanistan  2004          20.064968        10.9              7.75
# ...           ...   ...                ...         ...               ...
# 3644     Zimbabwe  2016          42.561730        29.8             62.88
# 3645     Zimbabwe  2017          44.178635        29.8             62.33
# 3646     Zimbabwe  2018          45.572647        29.9             82.53
# 3647     Zimbabwe  2019          46.781475        30.1             81.40
# 3648     Zimbabwe  2020          52.747670        30.4             80.61
#
#       Financial flows to developing countries (US $)  \
# ...

# %%
df['Name'].value_counts().head(10).plot(kind='bar', title='top 10 genres in top 50 Spotify songs')
# Out:
# <Axes: title={'center': 'top 10 genres in top 50 Spotify songs'}>

# %%
df.columns
# Out:
# Index(['Index', 'Name', 'Area', 'Review_Date', 'Rating_attribute',
#        'Rating(Out of 10)', 'Review_Text'],
#       dtype='object')

# %%
sns.pairplot(df, vars=['Area', 'Rating(Out of 10)'])

# %%
df_corr = df[['Index', 'Name', 'Area', 'Review_Date', 'Rating_attribute','Rating(Out of 10)', 'Review_Text']].corr()
df.corr()
# Out:
# C:\Users\j.a.aguilar.puch\AppData\Local\Temp\ipykernel_23084\2828352965.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df[['Index', 'Name', 'Area', 'Review_Date', 'Rating_attribute','Rating(Out of 10)', 'Review_Text']].corr()
# C:\Users\j.a.aguilar.puch\AppData\Local\Temp\ipykernel_23084\2828352965.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       Index  Rating(Out of 10)
# Index              1.000000          -0.208666
# Rating(Out of 10) -0.208666           1.000000
